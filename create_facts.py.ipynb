# %%
import csv

csvfile = open("laptops.csv", newline='')
reader = csv.DictReader(csvfile)
i =1
for row in reader:
	row['id'] = i
	i = i+1
	row['comments'] = row['comments'].replace('\n',' ')
	print(f"% Facts for {row['brand']} {row['model']}")
	print(f"laptop({str(row['id'])}).")
	print(f"brand({str(row['id'])},\'{row['brand']}\').")
	print(f"model({str(row['id'])},\'{row['model']}\').")
	print(f"ram({str(row['id'])},{row['ram']}).")
	print(f"hd_type({str(row['id'])},\'{row['hd_type']}\').")
	print(f"hd_size({str(row['id'])},{row['hd_size']}).")
	print(f"screen_size({str(row['id'])},{row['screen_size']}).")
	print(f"price({str(row['id'])},{row['price']}).")
	print(f"processor_brand({str(row['id'])},\'{row['processor_brand']}\').")
	print(f"processor_model({str(row['id'])},\'{row['processor_model']}\').")
	if row['clock_speed']:
		print(f"clock_speed({str(row['id'])},{row['clock_speed']}).")
	else:
		print(f"clock_speed({str(row['id'])},0).")
	if row['graphic_card_brand']:
		print(f"gc_brand({str(row['id'])},\'{row['graphic_card_brand']}\').")
	else:
		print(f"gc_brand({str(row['id'])},0).")
	if row['graphic_card_size']:
		print(f"gc_size({str(row['id'])},{row['graphic_card_size']}).")
	else:
		print(f"gc_size({str(row['id'])},0).")
	print(f"os({str(row['id'])},\'{row['os']}\').")
	if row['weight']:
		print(f"weight({str(row['id'])},{row['weight']}).")
	else:
		print(f"weight({str(row['id'])},1).")
	print(f"comments({str(row['id'])},\'{row['comments']}\').")
	print()
	print()
# Out:
# % Facts for Dell Inspiron 15-3567
# laptop(1).
# brand(1,'Dell').
# model(1,'Inspiron 15-3567').
# ram(1,4).
# hd_type(1,'hdd').
# hd_size(1,1024).
# screen_size(1,15.6).
# price(1,40000).
# processor_brand(1,'intel').
# processor_model(1,'i5').
# clock_speed(1,2.5).
# gc_brand(1,'intel').
# gc_size(1,0).
# os(1,'linux').
# weight(1,2.5).
# comments(1,'').
#
#
# % Facts for Apple MacBook Air
# laptop(2).
# brand(2,'Apple').
# model(2,'MacBook Air').
# ram(2,8).
# hd_type(2,'ssd').
# hd_size(2,128).
# screen_size(2,13.3).
# price(2,55499).
# processor_brand(2,'intel').
# processor_model(2,'i5').
# clock_speed(2,1.8).
# gc_brand(2,'intel').
# gc_size(2,2).
# os(2,'mac').
# weight(2,1.35).
# comments(2,'').
#
#
# % Facts for Apple MacBook Air
# laptop(3).
# brand(3,'Apple').
# model(3,'MacBook Air').
# ram(3,8).
# hd_type(3,'ssd').
# hd_size(3,256).
# screen_size(3,13.3).
# price(3,71500).
# processor_brand(3,'intel').
# processor_model(3,'i5').
# clock_speed(3,1.8).
# gc_brand(3,'intel').
# gc_size(3,2).
# os(3,'mac').
# weight(3,1.35).
# comments(3,'').
#
#
# % Facts for Apple MacBook Pro
# laptop(4).
# brand(4,'Apple').
# model(4,'MacBook Pro').
# ram(4,8).
# hd_type(4,'ssd').
# hd_size(4,128).
# screen_size(4,13.3).
# price(4,96890).
# processor_brand(4,'intel').
# processor_model(4,'i5').
# clock_speed(4,2.3).
# gc_brand(4,'intel').
# gc_size(4,2).
# os(4,'mac').
# weight(4,3.02).
# comments(4,'').
#
#
# % Facts for Apple MacBook Pro
# laptop(5).
# brand(5,'Apple').
# model(5,'MacBook Pro').
# ram(5,8).
# hd_type(5,'ssd').
# hd_size(5,256).
# screen_size(5,13.3).
# price(5,112666).
# processor_brand(5,'intel').
# processor_model(5,'i5').
# clock_speed(5,2.3).
# gc_brand(5,'intel').
# gc_size(5,2).
# os(5,'mac').
# weight(5,3.02).
# comments(5,'').
#
#
# % Facts for Apple MacBook Pro (TouchBar)
# laptop(6).
# brand(6,'Apple').
# model(6,'MacBook Pro (TouchBar)').
# ram(6,16).
# hd_type(6,'ssd').
# hd_size(6,512).
# screen_size(6,15).
# price(6,226000).
# processor_brand(6,'intel').
# processor_model(6,'i7').
# clock_speed(6,2.7).
# gc_brand(6,'intel').
# gc_size(6,2).
# os(6,'mac').
# weight(6,2.5).
# comments(6,'').
#
#
# % Facts for Apple MacBook Pro (TouchBar)
# laptop(7).
# brand(7,'Apple').
# model(7,'MacBook Pro (TouchBar)').
# ram(7,16).
# hd_type(7,'ssd').
# hd_size(7,512).
# screen_size(7,13.3).
# price(7,158000).
# processor_brand(7,'intel').
# processor_model(7,'i5').
# clock_speed(7,2.9).
# gc_brand(7,'intel').
# gc_size(7,2).
# os(7,'mac').
# weight(7,1.37).
# comments(7,'').
#
#
# % Facts for Apple MacBook
# laptop(8).
# brand(8,'Apple').
# model(8,'MacBook ').
# ram(8,8).
# hd_type(8,'ssd').
# hd_size(8,256).
# screen_size(8,12).
# price(8,96990).
# processor_brand(8,'intel').
# processor_model(8,'core m').
# clock_speed(8,1.2).
# gc_brand(8,'intel').
# gc_size(8,2).
# os(8,'mac').
# weight(8,0.92).
# comments(8,'').
#
#
# % Facts for Dell Vostro 3468
# laptop(9).
# brand(9,'Dell').
# model(9,'Vostro 3468').
# ram(9,4).
# hd_type(9,'hdd').
# hd_size(9,1024).
# screen_size(9,14).
# price(9,33225).
# processor_brand(9,'intel').
# processor_model(9,'i3').
# clock_speed(9,2.4).
# gc_brand(9,'intel').
# gc_size(9,0).
# os(9,'linux').
# weight(9,1.76).
# comments(9,'Integrated Graphics').
#
#
# % Facts for Dell Inspiron 15.6 3552
# laptop(10).
# brand(10,'Dell').
# model(10,'Inspiron 15.6 3552').
# ram(10,4).
# hd_type(10,'hdd').
# hd_size(10,500).
# screen_size(10,15).
# price(10,21990).
# processor_brand(10,'intel').
# processor_model(10,'pentium N3710').
# clock_speed(10,1.6).
# gc_brand(10,'intel').
# gc_size(10,0).
# os(10,'linux').
# weight(10,2.19).
# comments(10,'Integrated Graphics').
#
#
# % Facts for Dell Vostro 3468
# laptop(11).
# brand(11,'Dell').
# model(11,'Vostro 3468 ').
# ram(11,4).
# hd_type(11,'hdd').
# hd_size(11,1024).
# screen_size(11,14).
# price(11,35925).
# processor_brand(11,'intel').
# processor_model(11,'i3 ').
# clock_speed(11,2.4).
# gc_brand(11,'intel').
# gc_size(11,0).
# os(11,'windows').
# weight(11,1.76).
# comments(11,'Integrated Graphics').
#
#
# % Facts for Dell Inspiron 14 3442
# laptop(12).
# brand(12,'Dell').
# model(12,'Inspiron 14 3442').
# ram(12,4).
# hd_type(12,'hdd').
# hd_size(12,500).
# screen_size(12,14).
# price(12,30900).
# processor_brand(12,'intel').
# processor_model(12,'i3').
# clock_speed(12,1.7).
# gc_brand(12,'intel').
# gc_size(12,0).
# os(12,'linux').
# weight(12,3.1).
# comments(12,'Integrated Graphics').
#
#
# % Facts for Dell Inspiron 15 3567
# laptop(13).
# brand(13,'Dell').
# model(13,'Inspiron 15 3567').
# ram(13,4).
# hd_type(13,'hdd').
# hd_size(13,1024).
# screen_size(13,15.6).
# price(13,35990).
# processor_brand(13,'intel').
# processor_model(13,'i3').
# clock_speed(13,2.3).
# gc_brand(13,'intel').
# gc_size(13,0).
# os(13,'windows').
# weight(13,3.24).
# comments(13,'Integrated Graphics').
#
#
# % Facts for Dell Vostro 3568
# laptop(14).
# brand(14,'Dell').
# model(14,'Vostro 3568').
# ram(14,4).
# hd_type(14,'hdd').
# hd_size(14,500).
# screen_size(14,15.6).
# price(14,24900).
# processor_brand(14,'intel').
# processor_model(14,'Celeron 3855U').
# clock_speed(14,1.6).
# gc_brand(14,'intel').
# gc_size(14,0).
# os(14,'linux').
# weight(14,2.5).
# comments(14,'Integrated Graphics').
#
#
# % Facts for Dell Inspiron 15 3565
# laptop(15).
# brand(15,'Dell').
# model(15,'Inspiron 15 3565').
# ram(15,4).
# hd_type(15,'hdd').
# hd_size(15,500).
# screen_size(15,15).
# price(15,20990).
# processor_brand(15,'amd').
# processor_model(15,'E2').
# clock_speed(15,1.8).
# gc_brand(15,'amd').
# gc_size(15,0).
# os(15,'linux').
# weight(15,2.3).
# comments(15,'Integrated Graphics').
#
#
# % Facts for Acer Predator Helios 300
# laptop(16).
# brand(16,'Acer').
# model(16,'Predator Helios 300').
# ram(16,16).
# hd_type(16,'ssd').
# hd_size(16,1024).
# screen_size(16,15.6).
# price(16,101839).
# processor_brand(16,'intel').
# processor_model(16,'i7').
# clock_speed(16,2.8).
# gc_brand(16,'nvidia').
# gc_size(16,6).
# os(16,'windows').
# weight(16,2.7).
# comments(16,'Gaming Laptop').
#
#
# % Facts for Dell Latitude 3480
# laptop(17).
# brand(17,'Dell').
# model(17,'Latitude 3480').
# ram(17,4).
# hd_type(17,'hdd').
# hd_size(17,500).
# screen_size(17,14).
# price(17,28870).
# processor_brand(17,'intel').
# processor_model(17,'i3').
# clock_speed(17,2).
# gc_brand(17,'intel').
# gc_size(17,0).
# os(17,'linux').
# weight(17,1.8).
# comments(17,'Integrated Graphics').
#
#
# % Facts for Acer Nitro 5
# laptop(18).
# brand(18,'Acer').
# model(18,'Nitro 5').
# ram(18,8).
# hd_type(18,'ssd').
# hd_size(18,256).
# screen_size(18,15.6).
# price(18,72784).
# processor_brand(18,'amd').
# processor_model(18,'FX 9830P').
# clock_speed(18,3).
# gc_brand(18,'amd').
# gc_size(18,4000).
# os(18,'windows').
# weight(18,2.7).
# comments(18,'').
#
#
# % Facts for Dell Inspiron 5559
# laptop(19).
# brand(19,'Dell').
# model(19,'Inspiron 5559').
# ram(19,4).
# hd_type(19,'hdd').
# hd_size(19,1024).
# screen_size(19,15.6).
# price(19,34980).
# processor_brand(19,'intel').
# processor_model(19,'i3').
# clock_speed(19,2.3).
# gc_brand(19,'intel').
# gc_size(19,0).
# os(19,'windows').
# weight(19,2.5).
# comments(19,'Integrated Graphics').
#
#
# % Facts for Acer Aspire E5- 575G- 51VA
# laptop(20).
# brand(20,'Acer').
# model(20,'Aspire E5- 575G- 51VA').
# ram(20,8).
# hd_type(20,'hdd').
# hd_size(20,1024).
# screen_size(20,15.6).
# price(20,50331).
# processor_brand(20,'intel').
# processor_model(20,'i5').
# clock_speed(20,2.3).
# gc_brand(20,'nvidia').
# gc_size(20,0).
# os(20,'linux').
# weight(20,2.7).
# comments(20,'').
#
#
# % Facts for Acer Aspire F 15
# laptop(21).
# brand(21,'Acer').
# model(21,'Aspire F 15').
# ram(21,8).
# hd_type(21,'hdd').
# hd_size(21,1024).
# screen_size(21,15.6).
# price(21,59898).
# processor_brand(21,'intel').
# processor_model(21,'i5').
# clock_speed(21,2.8).
# gc_brand(21,'nvidia').
# gc_size(21,4).
# os(21,'windows').
# weight(21,2.3).
# comments(21,'').
#
#
# % Facts for Dell Inspiron 11 3148
# laptop(22).
# brand(22,'Dell').
# model(22,'Inspiron 11 3148').
# ram(22,4).
# hd_type(22,'hdd').
# hd_size(22,500).
# screen_size(22,11.6).
# price(22,25990).
# processor_brand(22,'intel').
# processor_model(22,'i3').
# clock_speed(22,1.9).
# gc_brand(22,'intel').
# gc_size(22,0).
# os(22,'windows').
# weight(22,1.4).
# comments(22,'integrated Graphics').
#
#
# % Facts for Acer E5-574G
# laptop(23).
# brand(23,'Acer').
# model(23,'E5-574G').
# ram(23,8).
# hd_type(23,'hdd').
# hd_size(23,1024).
# screen_size(23,15.6).
# price(23,53499).
# processor_brand(23,'intel').
# processor_model(23,'i5').
# clock_speed(23,2.3).
# gc_brand(23,'nvidia').
# gc_size(23,2).
# os(23,'windows').
# weight(23,2.4).
# comments(23,'').
#
#
# % Facts for Dell Inspiron 15 5555
# laptop(24).
# brand(24,'Dell').
# model(24,'Inspiron 15 5555').
# ram(24,8).
# hd_type(24,'hdd').
# hd_size(24,1024).
# screen_size(24,15.6).
# price(24,38590).
# processor_brand(24,'amd').
# processor_model(24,'A10-8700P').
# clock_speed(24,3.2).
# gc_brand(24,'amd').
# gc_size(24,0).
# os(24,'windows').
# weight(24,3.6).
# comments(24,'Integrated Graphics').
#
#
# % Facts for Acer Aspire NX.M8NSI.007
# laptop(25).
# brand(25,'Acer').
# model(25,'Aspire NX.M8NSI.007').
# ram(25,4).
# hd_type(25,'ssd').
# hd_size(25,60).
# screen_size(25,11.6).
# price(25,68999).
# processor_brand(25,'intel').
# processor_model(25,'i3').
# clock_speed(25,1.4).
# gc_brand(25,'intel').
# gc_size(25,0).
# os(25,'windows').
# weight(25,1.4).
# comments(25,'Integrated Graphics').
#
#
# % Facts for Dell Inspiron-15 5548
# laptop(26).
# brand(26,'Dell').
# model(26,'Inspiron-15 5548').
# ram(26,8).
# hd_type(26,'hdd').
# hd_size(26,1024).
# screen_size(26,15.6).
# price(26,38990).
# processor_brand(26,'intel').
# processor_model(26,'i5').
# clock_speed(26,2.7).
# gc_brand(26,'amd').
# gc_size(26,2).
# os(26,'windows').
# weight(26,3.2).
# comments(26,'').
#
#
# % Facts for Acer Spin 7 SP714-51
# laptop(27).
# brand(27,'Acer').
# model(27,'Spin 7 SP714-51').
# ram(27,8).
# hd_type(27,'hdd').
# hd_size(27,256).
# screen_size(27,14).
# price(27,124900).
# processor_brand(27,'intel').
# processor_model(27,'i7').
# clock_speed(27,3.6).
# gc_brand(27,'intel').
# gc_size(27,0).
# os(27,'windows').
# weight(27,1.2).
# comments(27,'Integrated Graphics').
#
#
# % Facts for Acer SF314-51
# laptop(28).
# brand(28,'Acer').
# model(28,'SF314-51').
# ram(28,4).
# hd_type(28,'hdd').
# hd_size(28,256).
# screen_size(28,14).
# price(28,74797).
# processor_brand(28,'intel').
# processor_model(28,'i5').
# clock_speed(28,2.5).
# gc_brand(28,'intel').
# gc_size(28,0).
# os(28,'windows').
# weight(28,1.5).
# comments(28,'Integrated Graphics').
#
#
# % Facts for Acer Swift 7 SF713-51
# laptop(29).
# brand(29,'Acer').
# model(29,'Swift 7 SF713-51').
# ram(29,8).
# hd_type(29,'ssd').
# hd_size(29,256).
# screen_size(29,13.3).
# price(29,80940).
# processor_brand(29,'intel').
# processor_model(29,'i5').
# clock_speed(29,3.2).
# gc_brand(29,'intel').
# gc_size(29,0).
# os(29,'windows').
# weight(29,1.125).
# comments(29,'Integrated Graphics').
#
#
# % Facts for Acer Aspire F5 572G
# laptop(30).
# brand(30,'Acer').
# model(30,'Aspire F5 572G').
# ram(30,8).
# hd_type(30,'hdd').
# hd_size(30,1024).
# screen_size(30,15.6).
# price(30,50680).
# processor_brand(30,'intel').
# processor_model(30,'i7').
# clock_speed(30,2.5).
# gc_brand(30,'intel').
# gc_size(30,2).
# os(30,'linux').
# weight(30,2.4).
# comments(30,'').
#
#
# % Facts for Acer ASPIRE V NITRO
# laptop(31).
# brand(31,'Acer').
# model(31,'ASPIRE V NITRO').
# ram(31,12).
# hd_type(31,'hdd').
# hd_size(31,1024).
# screen_size(31,15.6).
# price(31,105300).
# processor_brand(31,'intel').
# processor_model(31,'i7').
# clock_speed(31,2.6).
# gc_brand(31,'nvidia').
# gc_size(31,4).
# os(31,'windows').
# weight(31,2.4).
# comments(31,'').
#
#
# % Facts for Acer Predator 17
# laptop(32).
# brand(32,'Acer').
# model(32,'Predator 17').
# ram(32,16).
# hd_type(32,'ssd').
# hd_size(32,256).
# screen_size(32,17.3).
# price(32,178912).
# processor_brand(32,'intel').
# processor_model(32,'i7').
# clock_speed(32,2.6).
# gc_brand(32,'nvidia').
# gc_size(32,0).
# os(32,'windows').
# weight(32,4.2).
# comments(32,'Integrated Graphics').
#
#
# % Facts for Acer Aspire-V VN7-591G
# laptop(33).
# brand(33,'Acer').
# model(33,'Aspire-V VN7-591G').
# ram(33,12).
# hd_type(33,'hdd').
# hd_size(33,1024).
# screen_size(33,15.6).
# price(33,105510).
# processor_brand(33,'intel').
# processor_model(33,'i7').
# clock_speed(33,2.6).
# gc_brand(33,'nvidia').
# gc_size(33,1).
# os(33,'windows').
# weight(33,2.4).
# comments(33,'').
#
#
# % Facts for Acer Swift 3
# laptop(34).
# brand(34,'Acer').
# model(34,'Swift 3').
# ram(34,8).
# hd_type(34,'ssd').
# hd_size(34,256).
# screen_size(34,14).
# price(34,69999).
# processor_brand(34,'intel').
# processor_model(34,'i5').
# clock_speed(34,3.1).
# gc_brand(34,'intel').
# gc_size(34,0).
# os(34,'windows').
# weight(34,1.525).
# comments(34,'Integrated Graphics').
#
#
# % Facts for HP Omen W 250TX
# laptop(35).
# brand(35,'HP').
# model(35,'Omen W 250TX').
# ram(35,16).
# hd_type(35,'ssd').
# hd_size(35,256).
# screen_size(35,17.6).
# price(35,169990).
# processor_brand(35,'intel').
# processor_model(35,'i7').
# clock_speed(35,3.6).
# gc_brand(35,'nvidia').
# gc_size(35,8).
# os(35,'windows').
# weight(35,2.7).
#  Discover desktop-class gaming on a notebook with the next-generation GeForce GTX 1050M/1060M/1070M.** Plus, get improved battery life you need to game longer, unplugged.').
#
#
# % Facts for HP Omen AX248TX
# laptop(36).
# brand(36,'HP').
# model(36,'Omen AX248TX').
# ram(36,8).
# hd_type(36,'hdd').
# hd_size(36,1024).
# screen_size(36,15.6).
# price(36,74990).
# processor_brand(36,'intel').
# processor_model(36,'i5').
# clock_speed(36,2.6).
# gc_brand(36,'nvidia').
# gc_size(36,2).
# os(36,'windows').
# weight(36,2.5).
# comments(36,'Windows 10 Home').
#
#
# % Facts for HP Omen 15-ce074tx
# laptop(37).
# brand(37,'HP').
# model(37,'Omen 15-ce074tx').
# ram(37,16).
# hd_type(37,'ssd').
# hd_size(37,128).
# screen_size(37,15.6).
# price(37,143990).
# processor_brand(37,'intel').
# processor_model(37,'i7').
# clock_speed(37,2.8).
# gc_brand(37,'nvidia').
# gc_size(37,6).
# os(37,'windows').
# weight(37,2.6).
# comments(37,'Windows 10 Home').
#
#
# % Facts for HP 13-D116TU
# laptop(38).
# brand(38,'HP').
# model(38,'13-D116TU').
# ram(38,8).
# hd_type(38,'ssd').
# hd_size(38,256).
# screen_size(38,13.3).
# price(38,93410).
# processor_brand(38,'intel').
# processor_model(38,'i5').
# clock_speed(38,2.3).
# gc_brand(38,'intel').
# gc_size(38,0).
# os(38,'windows').
# weight(38,1.35).
# comments(38,'').
#
#
# % Facts for HP 13-D115TU
# laptop(39).
# brand(39,'HP').
# model(39,'13-D115TU').
# ram(39,8).
# hd_type(39,'ssd').
# hd_size(39,256).
# screen_size(39,13.3).
# price(39,101882).
# processor_brand(39,'intel').
# processor_model(39,'i7').
# clock_speed(39,2.5).
# gc_brand(39,'intel').
# gc_size(39,1).
# os(39,'windows').
# weight(39,1).
# comments(39,'').
#
#
# % Facts for HP 13-d015TU
# laptop(40).
# brand(40,'HP').
# model(40,'13-d015TU').
# ram(40,4).
# hd_type(40,'ssd').
# hd_size(40,256).
# screen_size(40,13.3).
# price(40,75990).
# processor_brand(40,'intel').
# processor_model(40,'i5').
# clock_speed(40,2.3).
# gc_brand(40,'intel').
# gc_size(40,0).
# os(40,'windows').
# weight(40,1).
# comments(40,'').
#
#
# % Facts for Acer Nitro 5 Spin NP-515-51
# laptop(41).
# brand(41,'Acer').
# model(41,'Nitro 5 Spin NP-515-51').
# ram(41,8).
# hd_type(41,'hdd').
# hd_size(41,1024).
# screen_size(41,15.6).
# price(41,87990).
# processor_brand(41,'intel').
# processor_model(41,'i5').
# clock_speed(41,1.6).
# gc_brand(41,'nvidia').
# gc_size(41,4).
# os(41,'windows').
# weight(41,2.2).
# comments(41,'').
#
#
# % Facts for HP 13-ac058TU
# laptop(42).
# brand(42,'HP').
# model(42,'13-ac058TU').
# ram(42,8).
# hd_type(42,'ssd').
# hd_size(42,360).
# screen_size(42,13.3).
# price(42,115290).
# processor_brand(42,'intel').
# processor_model(42,'i5').
# clock_speed(42,2.5).
# gc_brand(42,'intel').
# gc_size(42,0).
# os(42,'windows').
# weight(42,1.32).
# comments(42,'').
#
#
# % Facts for Acer Aspire E 15
# laptop(43).
# brand(43,'Acer').
# model(43,'Aspire E 15').
# ram(43,8).
# hd_type(43,'hdd').
# hd_size(43,1024).
# screen_size(43,15.6).
# price(43,73756).
# processor_brand(43,'intel').
# processor_model(43,'i5').
# clock_speed(43,2.3).
# gc_brand(43,'nvidia').
# gc_size(43,2).
# os(43,'windows').
# weight(43,2.4).
# comments(43,'').
#
#
# % Facts for HP  Pavilion 15-cc102TX
# laptop(44).
# brand(44,'HP ').
# model(44,'Pavilion 15-cc102TX').
# ram(44,8).
# hd_type(44,'hdd').
# hd_size(44,1024).
# screen_size(44,15.6).
# price(44,59990).
# processor_brand(44,'intel').
# processor_model(44,'i5').
# clock_speed(44,1.6).
# gc_brand(44,'nvidia').
# gc_size(44,2).
# os(44,'windows').
# weight(44,2.12).
# comments(44,'').
#
#
# % Facts for HP 13-ac059TU
# laptop(45).
# brand(45,'HP').
# model(45,'13-ac059TU').
# ram(45,16).
# hd_type(45,'ssd').
# hd_size(45,512).
# screen_size(45,13.3).
# price(45,169280).
# processor_brand(45,'intel').
# processor_model(45,'i7').
# clock_speed(45,2.7).
# gc_brand(45,'intel').
# gc_size(45,0).
# os(45,'windows').
# weight(45,1).
# comments(45,'').
#
#
# % Facts for Lenovo 300â€“15IBR
# laptop(46).
# brand(46,'Lenovo').
# model(46,'300â€“15IBR').
# ram(46,8).
# hd_type(46,'hdd').
# hd_size(46,1024).
# screen_size(46,15.6).
# price(46,40990).
# processor_brand(46,'intel').
# processor_model(46,'i5').
# clock_speed(46,2.3).
# gc_brand(46,'amd').
# gc_size(46,2).
# os(46,'linux').
# weight(46,3.2).
# comments(46,'2.7 customer rating').
#
#
# % Facts for Acer Aspire 5 -A515-51G
# laptop(47).
# brand(47,'Acer').
# model(47,'Aspire 5 -A515-51G ').
# ram(47,8).
# hd_type(47,'hdd').
# hd_size(47,1024).
# screen_size(47,15.6).
# price(47,37990).
# processor_brand(47,'intel').
# processor_model(47,'i5').
# clock_speed(47,2.5).
# gc_brand(47,'nvidia').
# gc_size(47,0).
# os(47,'linux').
# weight(47,2.2).
# comments(47,'').
#
#
# % Facts for HP 13-v122TU
# laptop(48).
# brand(48,'HP').
# model(48,'13-v122TU').
# ram(48,8).
# hd_type(48,'ssd').
# hd_size(48,512).
# screen_size(48,13.3).
# price(48,143999).
# processor_brand(48,'intel').
# processor_model(48,'i7').
# clock_speed(48,2.7).
# gc_brand(48,'intel').
# gc_size(48,0).
# os(48,'windows').
# weight(48,1.11).
# comments(48,'').
#
#
# % Facts for Dell Inspiron 7560
# laptop(49).
# brand(49,'Dell').
# model(49,'Inspiron 7560').
# ram(49,8).
# hd_type(49,'hdd').
# hd_size(49,1024).
# screen_size(49,15.6).
# price(49,81369).
# processor_brand(49,'intel').
# processor_model(49,'i7').
# clock_speed(49,2.7).
# gc_brand(49,'nvidia').
# gc_size(49,4).
# os(49,'windows').
# weight(49,3.1).
# comments(49,'').
#
#
# % Facts for Acer Aspire R 14 R3-431T-P3RD
# laptop(50).
# brand(50,'Acer').
# model(50,'Aspire R 14 R3-431T-P3RD').
# ram(50,4).
# hd_type(50,'hdd').
# hd_size(50,500).
# screen_size(50,14).
# price(50,63347).
# processor_brand(50,'intel').
# processor_model(50,'Pentium 3805U').
# clock_speed(50,1.9).
# gc_brand(50,'intel').
# gc_size(50,0).
# os(50,'windows').
# weight(50,2.2).
# comments(50,'Integrated Graphics').
#
#
# % Facts for HP 15q-bu004tu
# laptop(51).
# brand(51,'HP').
# model(51,'15q-bu004tu').
# ram(51,4).
# hd_type(51,'hdd').
# hd_size(51,1024).
# screen_size(51,15.6).
# price(51,27990).
# processor_brand(51,'intel').
# processor_model(51,'i3').
# clock_speed(51,2).
# gc_brand(51,'intel').
# gc_size(51,0).
# os(51,'linux').
# weight(51,2.1).
# comments(51,'').
#
#
# % Facts for HP  Pavilion 15-au620TX
# laptop(52).
# brand(52,'HP ').
# model(52,'Pavilion 15-au620TX').
# ram(52,8).
# hd_type(52,'hdd').
# hd_size(52,1024).
# screen_size(52,15.6).
# price(52,55290).
# processor_brand(52,'intel').
# processor_model(52,'i5').
# clock_speed(52,2.5).
# gc_brand(52,'nvidia').
# gc_size(52,2).
# os(52,'windows').
# weight(52,2.03).
# comments(52,'').
#
#
# % Facts for Lenovo G50-80
# laptop(53).
# brand(53,'Lenovo').
# model(53,'G50-80').
# ram(53,8).
# hd_type(53,'hdd').
# hd_size(53,1024).
# screen_size(53,15.6).
# price(53,41790).
# processor_brand(53,'intel').
# processor_model(53,'i3').
# clock_speed(53,2).
# gc_brand(53,'amd').
# gc_size(53,2).
# os(53,'windows').
# weight(53,2.5).
# comments(53,'customer rating 3.3').
#
#
# % Facts for Acer Aspire E5-573G
# laptop(54).
# brand(54,'Acer').
# model(54,'Aspire E5-573G').
# ram(54,8).
# hd_type(54,'hdd').
# hd_size(54,1024).
# screen_size(54,15.6).
# price(54,87576).
# processor_brand(54,'intel').
# processor_model(54,'i5').
# clock_speed(54,2.2).
# gc_brand(54,'intel').
# gc_size(54,0).
# os(54,'windows').
# weight(54,2.4).
# comments(54,'Integrated Graphics').
#
#
# % Facts for HP  Pavilion 15-au620TX
# laptop(55).
# brand(55,'HP ').
# model(55,'Pavilion 15-au620TX').
# ram(55,8).
# hd_type(55,'hdd').
# hd_size(55,1024).
# screen_size(55,15.6).
# price(55,60990).
# processor_brand(55,'intel').
# processor_model(55,'i5').
# clock_speed(55,2.5).
# gc_brand(55,'nvidia').
# gc_size(55,4).
# os(55,'windows').
# weight(55,2.03).
# comments(55,'').
#
#
# % Facts for Lenovo IP310
# laptop(56).
# brand(56,'Lenovo').
# model(56,'IP310').
# ram(56,8).
# hd_type(56,'hdd').
# hd_size(56,1024).
# screen_size(56,15.6).
# price(56,41990).
# processor_brand(56,'intel').
# processor_model(56,'i5').
# clock_speed(56,2.5).
# gc_brand(56,'nvidia').
# gc_size(56,2).
# os(56,'linux').
# weight(56,2.8).
# comments(56,'customer rating 3.8').
#
#
# % Facts for Acer Premium
# laptop(57).
# brand(57,'Acer').
# model(57,'Premium').
# ram(57,8).
# hd_type(57,'hdd').
# hd_size(57,1024).
# screen_size(57,15.6).
# price(57,72112).
# processor_brand(57,'intel').
# processor_model(57,'i5').
# clock_speed(57,2.3).
# gc_brand(57,'nvidia').
# gc_size(57,2).
# os(57,'windows').
# weight(57,2.4).
# comments(57,'').
#
#
# % Facts for Dell Inspiron 15 Gaming 5577
# laptop(58).
# brand(58,'Dell').
# model(58,'Inspiron 15 Gaming 5577').
# ram(58,8).
# hd_type(58,'hdd').
# hd_size(58,1024).
# screen_size(58,15.6).
# price(58,72490).
# processor_brand(58,'intel').
# processor_model(58,'i5').
# clock_speed(58,3.5).
# gc_brand(58,'nvidia').
# gc_size(58,4).
# os(58,'windows').
# weight(58,2.6).
# comments(58,'').
#
#
# % Facts for HP  Pavilion 15-au620TX
# laptop(59).
# brand(59,'HP ').
# model(59,'Pavilion 15-au620TX ').
# ram(59,8).
# hd_type(59,'hdd').
# hd_size(59,1024).
# screen_size(59,14).
# price(59,62990).
# processor_brand(59,'intel').
# processor_model(59,'i5').
# clock_speed(59,2.5).
# gc_brand(59,'nvidia').
# gc_size(59,2).
# os(59,'windows').
# weight(59,2.03).
# comments(59,'').
#
#
# % Facts for Lenovo 310 80TV00XXIH
# laptop(60).
# brand(60,'Lenovo').
# model(60,'310 80TV00XXIH').
# ram(60,8).
# hd_type(60,'hdd').
# hd_size(60,1024).
# screen_size(60,15.6).
# price(60,41990).
# processor_brand(60,'intel').
# processor_model(60,'i5').
# clock_speed(60,2.5).
# gc_brand(60,'nvidia').
# gc_size(60,2).
# os(60,'linux').
# weight(60,2.2).
# comments(60,'customer rating 3.5').
#
#
# % Facts for Dell Inspiron 15 7000 7567
# laptop(61).
# brand(61,'Dell').
# model(61,'Inspiron 15 7000 7567').
# ram(61,16).
# hd_type(61,'ssd').
# hd_size(61,128).
# screen_size(61,15.6).
# price(61,99991).
# processor_brand(61,'intel').
# processor_model(61,'i7').
# clock_speed(61,2.8).
# gc_brand(61,'nvidia').
# gc_size(61,4).
# os(61,'windows').
# weight(61,2.8).
# comments(61,'').
#
#
# % Facts for HP 14q-bu008tu (2UL54PA)
# laptop(62).
# brand(62,'HP').
# model(62,'14q-bu008tu (2UL54PA)').
# ram(62,4).
# hd_type(62,'hdd').
# hd_size(62,1024).
# screen_size(62,14).
# price(62,39990).
# processor_brand(62,'intel').
# processor_model(62,'i5').
# clock_speed(62,2.5).
# gc_brand(62,'intel').
# gc_size(62,0).
# os(62,'windows').
# weight(62,1.9).
# comments(62,'').
#
#
# % Facts for Acer Switch 10E SW3-016
# laptop(63).
# brand(63,'Acer').
# model(63,'Switch 10E SW3-016 ').
# ram(63,2).
# hd_type(63,'ssd').
# hd_size(63,32).
# screen_size(63,10.1).
# price(63,11976).
# processor_brand(63,'intel').
# processor_model(63,'Atom Z8300').
# clock_speed(63,1.44).
# gc_brand(63,'intel').
# gc_size(63,0).
# os(63,'windows,linux').
# weight(63,1.2).
# comments(63,'').
#
#
# % Facts for HP  15-BR011TX
# laptop(64).
# brand(64,'HP ').
# model(64,'15-BR011TX').
# ram(64,8).
# hd_type(64,'hdd').
# hd_size(64,1024).
# screen_size(64,15.6).
# price(64,52690).
# processor_brand(64,'intel').
# processor_model(64,'i5').
# clock_speed(64,2.5).
# gc_brand(64,'amd').
# gc_size(64,2).
# os(64,'windows').
# weight(64,2.1).
# comments(64,'').
#
#
# % Facts for Dell Inspiron 15 Gaming 7567
# laptop(65).
# brand(65,'Dell').
# model(65,'Inspiron 15 Gaming 7567').
# ram(65,8).
# hd_type(65,'hdd').
# hd_size(65,1024).
# screen_size(65,15.6).
# price(65,91890).
# processor_brand(65,'intel').
# processor_model(65,'i7').
# clock_speed(65,3.8).
# gc_brand(65,'nvidia').
# gc_size(65,4).
# os(65,'windows').
# weight(65,2.8).
# comments(65,'').
#
#
# % Facts for Acer Nitro 5
# laptop(66).
# brand(66,'Acer').
# model(66,'Nitro 5').
# ram(66,16).
# hd_type(66,'ssd').
# hd_size(66,256).
# screen_size(66,14).
# price(66,131551).
# processor_brand(66,'intel').
# processor_model(66,'i5').
# clock_speed(66,3.5).
# gc_brand(66,'nvidia').
# gc_size(66,4).
# os(66,'windows').
# weight(66,2.7).
# comments(66,'').
#
#
# % Facts for HP  15-BR011TX
# laptop(67).
# brand(67,'HP ').
# model(67,'15-BR011TX').
# ram(67,8).
# hd_type(67,'hdd').
# hd_size(67,1024).
# screen_size(67,15.6).
# price(67,65590).
# processor_brand(67,'intel').
# processor_model(67,'i5').
# clock_speed(67,2.5).
# gc_brand(67,'amd').
# gc_size(67,4).
# os(67,'windows').
# weight(67,2.1).
# comments(67,'').
#
#
# % Facts for Lenovo 300-15ISK 80Q700DWIN
# laptop(68).
# brand(68,'Lenovo').
# model(68,'300-15ISK 80Q700DWIN').
# ram(68,4).
# hd_type(68,'hdd').
# hd_size(68,1024).
# screen_size(68,15.6).
# price(68,41990).
# processor_brand(68,'intel').
# processor_model(68,'i5').
# clock_speed(68,2.3).
# gc_brand(68,'amd').
# gc_size(68,2).
# os(68,'linux').
# weight(68,2.3).
# comments(68,'cutomer rating 3.6').
#
#
# % Facts for Dell Inspiron 5567
# laptop(69).
# brand(69,'Dell').
# model(69,'Inspiron 5567').
# ram(69,16).
# hd_type(69,'hdd').
# hd_size(69,2048).
# screen_size(69,15.6).
# price(69,84990).
# processor_brand(69,'intel').
# processor_model(69,'i7').
# clock_speed(69,3.5).
# gc_brand(69,'amd').
# gc_size(69,0).
# os(69,'windows').
# weight(69,2.4).
# comments(69,'').
#
#
# % Facts for HP 15q-BU008TX
# laptop(70).
# brand(70,'HP').
# model(70,'15q-BU008TX').
# ram(70,4).
# hd_type(70,'hdd').
# hd_size(70,1024).
# screen_size(70,15.6).
# price(70,33990).
# processor_brand(70,'intel').
# processor_model(70,'i3').
# clock_speed(70,2).
# gc_brand(70,'amd').
# gc_size(70,0).
# os(70,'linux').
# weight(70,2.1).
# comments(70,'').
#
#
# % Facts for HP  Pavilion 14-AL176TX
# laptop(71).
# brand(71,'HP ').
# model(71,'Pavilion 14-AL176TX').
# ram(71,8).
# hd_type(71,'hdd').
# hd_size(71,1024).
# screen_size(71,14).
# price(71,57990).
# processor_brand(71,'intel').
# processor_model(71,'i5').
# clock_speed(71,2.5).
# gc_brand(71,'nvidia').
# gc_size(71,2).
# os(71,'windows').
# weight(71,1.58).
# comments(71,'').
#
#
# % Facts for Dell Inspiron 15 5000 5567
# laptop(72).
# brand(72,'Dell').
# model(72,'Inspiron 15 5000 5567').
# ram(72,16).
# hd_type(72,'hdd').
# hd_size(72,2048).
# screen_size(72,15.6).
# price(72,86350).
# processor_brand(72,'intel').
# processor_model(72,'i7').
# clock_speed(72,3.5).
# gc_brand(72,'amd').
# gc_size(72,4).
# os(72,'windows').
# weight(72,2.4).
# comments(72,'').
#
#
# % Facts for HP  Pavilion x360 14-ba075TX
# laptop(73).
# brand(73,'HP ').
# model(73,'Pavilion x360 14-ba075TX ').
# ram(73,8).
# hd_type(73,'hdd').
# hd_size(73,1024).
# screen_size(73,14).
# price(73,51490).
# processor_brand(73,'intel').
# processor_model(73,'i3').
# clock_speed(73,2.4).
# gc_brand(73,'nvidia').
# gc_size(73,2).
# os(73,'windows').
# weight(73,1.72).
# comments(73,'').
#
#
# % Facts for Lenovo G50-80 80E503CMIH
# laptop(74).
# brand(74,'Lenovo').
# model(74,'G50-80 80E503CMIH').
# ram(74,8).
# hd_type(74,'hdd').
# hd_size(74,1024).
# screen_size(74,15.6).
# price(74,42500).
# processor_brand(74,'intel').
# processor_model(74,'i5').
# clock_speed(74,2.2).
# gc_brand(74,'amd').
# gc_size(74,2).
# os(74,'linux').
# weight(74,3.2).
# comments(74,'customer rating 3.8').
#
#
# % Facts for Acer Aspire ES1-523
# laptop(75).
# brand(75,'Acer').
# model(75,'Aspire ES1-523 ').
# ram(75,4).
# hd_type(75,'hdd').
# hd_size(75,1024).
# screen_size(75,15.6).
# price(75,19465).
# processor_brand(75,'amd').
# processor_model(75,'A4-7210').
# clock_speed(75,1.8).
# gc_brand(75,'amd').
# gc_size(75,0).
# os(75,'linux').
# weight(75,2.4).
# comments(75,'').
#
#
# % Facts for HP 15-bs541TU
# laptop(76).
# brand(76,'HP').
# model(76,'15-bs541TU').
# ram(76,4).
# hd_type(76,'hdd').
# hd_size(76,1024).
# screen_size(76,15.6).
# price(76,34990).
# processor_brand(76,'intel').
# processor_model(76,'i3').
# clock_speed(76,2).
# gc_brand(76,'intel').
# gc_size(76,0).
# os(76,'windows').
# weight(76,2.1).
# comments(76,'').
#
#
# % Facts for Dell Inspiron 15 Gaming 5577
# laptop(77).
# brand(77,'Dell').
# model(77,'Inspiron 15 Gaming 5577').
# ram(77,8).
# hd_type(77,'hdd').
# hd_size(77,1024).
# screen_size(77,15.6).
# price(77,83000).
# processor_brand(77,'intel').
# processor_model(77,'i7').
# clock_speed(77,3.8).
# gc_brand(77,'nvidia').
# gc_size(77,4).
# os(77,'windows').
# weight(77,2.6).
# comments(77,'').
#
#
# % Facts for HP 15-bs541TU
# laptop(78).
# brand(78,'HP').
# model(78,'15-bs541TU').
# ram(78,8).
# hd_type(78,'hdd').
# hd_size(78,1024).
# screen_size(78,15.6).
# price(78,36590).
# processor_brand(78,'intel').
# processor_model(78,'i3').
# clock_speed(78,2).
# gc_brand(78,'amd').
# gc_size(78,0).
# os(78,'linux').
# weight(78,2.1).
# comments(78,'').
#
#
# % Facts for Lenovo 59422410
# laptop(79).
# brand(79,'Lenovo').
# model(79,'59422410').
# ram(79,8).
# hd_type(79,'hdd').
# hd_size(79,1024).
# screen_size(79,15.6).
# price(79,42190).
# processor_brand(79,'intel').
# processor_model(79,'i3').
# clock_speed(79,1.7).
# gc_brand(79,'amd').
# gc_size(79,2).
# os(79,'windows').
# weight(79,2.4).
# comments(79,'customer rating 3.9').
#
#
# % Facts for Dell Inspiron 5378
# laptop(80).
# brand(80,'Dell').
# model(80,'Inspiron 5378').
# ram(80,8).
# hd_type(80,'ssd').
# hd_size(80,256).
# screen_size(80,13.3).
# price(80,76585).
# processor_brand(80,'intel').
# processor_model(80,'i7').
# clock_speed(80,2.7).
# gc_brand(80,'intel').
# gc_size(80,2).
# os(80,'windows').
# weight(80,1.6).
# comments(80,'Laptop with Built-in Battery, AC Adapter with Power Cord, Manuals').
#
#
# % Facts for Lenovo 100 80QQ01BBIH
# laptop(81).
# brand(81,'Lenovo').
# model(81,'100 80QQ01BBIH').
# ram(81,4).
# hd_type(81,'hdd').
# hd_size(81,1024).
# screen_size(81,15.6).
# price(81,42790).
# processor_brand(81,'intel').
# processor_model(81,'i5').
# clock_speed(81,2.2).
# gc_brand(81,'nvidia').
# gc_size(81,2).
# os(81,'windows').
# weight(81,2.3).
# comments(81,'customer rating 2.9').
#
#
# % Facts for HP 15q-Bu014TU
# laptop(82).
# brand(82,'HP').
# model(82,'15q-Bu014TU ').
# ram(82,4).
# hd_type(82,'hdd').
# hd_size(82,1024).
# screen_size(82,15.6).
# price(82,39990).
# processor_brand(82,'intel').
# processor_model(82,'i5').
# clock_speed(82,2.5).
# gc_brand(82,'intel').
# gc_size(82,0).
# os(82,'windows').
# weight(82,2.1).
# comments(82,'').
#
#
# % Facts for HP L8E74UT#ABA
# laptop(83).
# brand(83,'HP').
# model(83,'L8E74UT#ABA').
# ram(83,2).
# hd_type(83,'ssd').
# hd_size(83,500).
# screen_size(83,11.6).
# price(83,40255).
# processor_brand(83,'intel').
# processor_model(83,'i5').
# clock_speed(83,0).
# gc_brand(83,'intel').
# gc_size(83,0).
# os(83,'windows').
# weight(83,1.28).
# comments(83,'').
#
#
# % Facts for Dell Inspiron 17 7567
# laptop(84).
# brand(84,'Dell').
# model(84,'Inspiron 17 7567').
# ram(84,16).
# hd_type(84,'ssd').
# hd_size(84,256).
# screen_size(84,15.6).
# price(84,119780).
# processor_brand(84,'intel').
# processor_model(84,'i7').
# clock_speed(84,2.8).
# gc_brand(84,0).
# gc_size(84,0).
# os(84,'windows').
# weight(84,4.1).
# comments(84,'').
#
#
# % Facts for Acer A315-31CDC UN.GNTSI.001
# laptop(85).
# brand(85,'Acer').
# model(85,'A315-31CDC UN.GNTSI.001').
# ram(85,2).
# hd_type(85,'ssd').
# hd_size(85,500).
# screen_size(85,15.6).
# price(85,17990).
# processor_brand(85,'intel').
# processor_model(85,'Celeron').
# clock_speed(85,1.1).
# gc_brand(85,'intel').
# gc_size(85,0).
# os(85,'windows').
# weight(85,2.1).
# comments(85,'').
#
#
# % Facts for Lenovo G50-80 80E5021EIN
# laptop(86).
# brand(86,'Lenovo').
# model(86,'G50-80 80E5021EIN').
# ram(86,4).
# hd_type(86,'hdd').
# hd_size(86,1024).
# screen_size(86,15.6).
# price(86,42990).
# processor_brand(86,'intel').
# processor_model(86,'i5').
# clock_speed(86,2.2).
# gc_brand(86,'intel').
# gc_size(86,0).
# os(86,'linux').
# weight(86,3.2).
# comments(86,'customer rating 3.4').
#
#
# % Facts for HP Pavilion x360 11-AD022TU
# laptop(87).
# brand(87,'HP').
# model(87,'Pavilion x360 11-AD022TU').
# ram(87,4).
# hd_type(87,'hdd').
# hd_size(87,1024).
# screen_size(87,11).
# price(87,39999).
# processor_brand(87,'intel').
# processor_model(87,'i3').
# clock_speed(87,2.4).
# gc_brand(87,'intel').
# gc_size(87,0).
# os(87,'windows').
# weight(87,1.39).
# comments(87,'').
#
#
# % Facts for Dell Inspiron 5567
# laptop(88).
# brand(88,'Dell').
# model(88,'Inspiron 5567').
# ram(88,16).
# hd_type(88,'hdd').
# hd_size(88,1024).
# screen_size(88,15.6).
# price(88,74985).
# processor_brand(88,'intel').
# processor_model(88,'i7').
# clock_speed(88,3.5).
# gc_brand(88,'amd').
# gc_size(88,0).
# os(88,'windows').
# weight(88,2.3).
# comments(88,'').
#
#
# % Facts for HP  15-au623Tx
# laptop(89).
# brand(89,'HP ').
# model(89,'15-au623Tx').
# ram(89,8).
# hd_type(89,'hdd').
# hd_size(89,1024).
# screen_size(89,15.5).
# price(89,59990).
# processor_brand(89,'intel').
# processor_model(89,'i5').
# clock_speed(89,2.5).
# gc_brand(89,'nvidia').
# gc_size(89,4).
# os(89,'windows').
# weight(89,2.9).
# comments(89,'').
#
#
# % Facts for HP 15-BS544TU
# laptop(90).
# brand(90,'HP').
# model(90,'15-BS544TU').
# ram(90,8).
# hd_type(90,'hdd').
# hd_size(90,1024).
# screen_size(90,15.6).
# price(90,32849).
# processor_brand(90,'intel').
# processor_model(90,'i3').
# clock_speed(90,2).
# gc_brand(90,'intel').
# gc_size(90,0).
# os(90,'linux').
# weight(90,2.1).
# comments(90,'').
#
#
# % Facts for Lenovo 320E 80XL0378IN
# laptop(91).
# brand(91,'Lenovo').
# model(91,'320E 80XL0378IN').
# ram(91,4).
# hd_type(91,'hdd').
# hd_size(91,1024).
# screen_size(91,15.6).
# price(91,43990).
# processor_brand(91,'intel').
# processor_model(91,'i5').
# clock_speed(91,3.1).
# gc_brand(91,'intel').
# gc_size(91,2).
# os(91,'windows').
# weight(91,2.2).
# comments(91,'customer rating 3.2').
#
#
# % Facts for Alienware 15 Notebook
# laptop(92).
# brand(92,'Alienware').
# model(92,'15 Notebook').
# ram(92,16).
# hd_type(92,'hdd').
# hd_size(92,1024).
# screen_size(92,15.6).
# price(92,199000).
# processor_brand(92,'intel').
# processor_model(92,'i7').
# clock_speed(92,2.6).
# gc_brand(92,'nvidia').
# gc_size(92,8).
# os(92,'windows').
# weight(92,3.5).
# comments(92,'Maximum Display Resolution : 1920 x 1080 pixel').
#
#
# % Facts for Dell Inspiron 7378
# laptop(93).
# brand(93,'Dell').
# model(93,'Inspiron 7378').
# ram(93,8).
# hd_type(93,'ssd').
# hd_size(93,256).
# screen_size(93,13.3).
# price(93,77993).
# processor_brand(93,'intel').
# processor_model(93,'i7').
# clock_speed(93,2.7).
# gc_brand(93,0).
# gc_size(93,0).
# os(93,'windows').
# weight(93,2.8).
# comments(93,'').
#
#
# % Facts for HP 15-ay511tx
# laptop(94).
# brand(94,'HP').
# model(94,'15-ay511tx').
# ram(94,8).
# hd_type(94,'hdd').
# hd_size(94,1024).
# screen_size(94,15.6).
# price(94,41990).
# processor_brand(94,'intel').
# processor_model(94,'i3').
# clock_speed(94,2).
# gc_brand(94,'amd').
# gc_size(94,2).
# os(94,'windows').
# weight(94,2.19).
# comments(94,'').
#
#
# % Facts for Acer Aspire3 A315-51-356P
# laptop(95).
# brand(95,'Acer').
# model(95,'Aspire3 A315-51-356P ').
# ram(95,4).
# hd_type(95,'hdd').
# hd_size(95,1024).
# screen_size(95,15.6).
# price(95,30415).
# processor_brand(95,'intel').
# processor_model(95,'i3').
# clock_speed(95,2).
# gc_brand(95,'intel').
# gc_size(95,0).
# os(95,'windows').
# weight(95,2.2).
# comments(95,'').
#
#
# % Facts for Dell Inspiron 15 5578
# laptop(96).
# brand(96,'Dell').
# model(96,'Inspiron 15 5578').
# ram(96,16).
# hd_type(96,'ssd').
# hd_size(96,512).
# screen_size(96,15.6).
# price(96,76996).
# processor_brand(96,'intel').
# processor_model(96,'i7').
# clock_speed(96,2.7).
# gc_brand(96,'intel').
# gc_size(96,0).
# os(96,'windows').
# weight(96,2.3).
# comments(96,'').
#
#
# % Facts for HP HP AR004TU
# laptop(97).
# brand(97,'HP').
# model(97,'HP AR004TU').
# ram(97,4).
# hd_type(97,'hdd').
# hd_size(97,1024).
# screen_size(97,14).
# price(97,34668).
# processor_brand(97,'intel').
# processor_model(97,'i3').
# clock_speed(97,2).
# gc_brand(97,'intel').
# gc_size(97,0).
# os(97,'windows').
# weight(97,1.94).
# comments(97,'').
#
#
# % Facts for Alienware AW13R3-7000SLV-PUS
# laptop(98).
# brand(98,'Alienware').
# model(98,'AW13R3-7000SLV-PUS').
# ram(98,8).
# hd_type(98,'ssd').
# hd_size(98,256).
# screen_size(98,13.3).
# price(98,190256).
# processor_brand(98,'intel').
# processor_model(98,'i7').
# clock_speed(98,3).
# gc_brand(98,'nvidia').
# gc_size(98,6).
# os(98,'windows').
# weight(98,2.6).
#  1 Lithium ion batteries required. (included)').
#
#
# % Facts for HP  Pavilion 14-bf125tx
# laptop(99).
# brand(99,'HP ').
# model(99,'Pavilion 14-bf125tx ').
# ram(99,12).
# hd_type(99,'hdd').
# hd_size(99,1024).
# screen_size(99,14).
# price(99,64490).
# processor_brand(99,'intel').
# processor_model(99,'i5').
# clock_speed(99,1.6).
# gc_brand(99,'nvidia').
# gc_size(99,2).
# os(99,'windows').
# weight(99,1.53).
# comments(99,'').
#
#
# % Facts for Dell Inspiron 15 Gaming 7567
# laptop(100).
# brand(100,'Dell').
# model(100,'Inspiron 15 Gaming 7567').
# ram(100,16).
# hd_type(100,'hdd').
# hd_size(100,1280).
# screen_size(100,15.6).
# price(100,112990).
# processor_brand(100,'intel').
# processor_model(100,'i7').
# clock_speed(100,3.8).
# gc_brand(100,'nvidia').
# gc_size(100,4).
# os(100,'windows').
# weight(100,2.8).
#  Included Components:	Laptop, Battery, AC Adapter, User Guide, Manuals').
#
#
# % Facts for HP ay516tx
# laptop(101).
# brand(101,'HP').
# model(101,'ay516tx').
# ram(101,4).
# hd_type(101,'hdd').
# hd_size(101,1024).
# screen_size(101,15.6).
# price(101,42100).
# processor_brand(101,'intel').
# processor_model(101,'i5').
# clock_speed(101,2.3).
# gc_brand(101,'amd').
# gc_size(101,2).
# os(101,'windows').
# weight(101,1.28).
# comments(101,'').
#
#
# % Facts for Acer A315-31-P4CRUN.GNTSI.002
# laptop(102).
# brand(102,'Acer').
# model(102,'A315-31-P4CRUN.GNTSI.002').
# ram(102,4).
# hd_type(102,'hdd').
# hd_size(102,500).
# screen_size(102,15.6).
# price(102,18990).
# processor_brand(102,'intel').
# processor_model(102,'pentium').
# clock_speed(102,1.1).
# gc_brand(102,'intel').
# gc_size(102,0).
# os(102,'windows').
# weight(102,1).
# comments(102,'').
#
#
# % Facts for Lenovo 320E-15IKB 80XL03FYIN
# laptop(103).
# brand(103,'Lenovo').
# model(103,'320E-15IKB 80XL03FYIN').
# ram(103,4).
# hd_type(103,'hdd').
# hd_size(103,1024).
# screen_size(103,15).
# price(103,45589).
# processor_brand(103,'intel').
# processor_model(103,'i5').
# clock_speed(103,2.2).
# gc_brand(103,'amd').
# gc_size(103,2).
# os(103,'windows').
# weight(103,2.5).
# comments(103,'customer rating 3.8').
#
#
# % Facts for Dell Inspiron 15 7560
# laptop(104).
# brand(104,'Dell').
# model(104,'Inspiron 15 7560').
# ram(104,8).
# hd_type(104,'ssd').
# hd_size(104,128).
# screen_size(104,15.6).
# price(104,76000).
# processor_brand(104,'intel').
# processor_model(104,'i7').
# clock_speed(104,2.7).
# gc_brand(104,'nvidia').
# gc_size(104,4).
# os(104,'windows').
# weight(104,3.2).
# comments(104,'').
#
#
# % Facts for HP 15q-BU011TX
# laptop(105).
# brand(105,'HP').
# model(105,'15q-BU011TX').
# ram(105,8).
# hd_type(105,'hdd').
# hd_size(105,1024).
# screen_size(105,15.6).
# price(105,42990).
# processor_brand(105,'intel').
# processor_model(105,'i5').
# clock_speed(105,2.5).
# gc_brand(105,'amd').
# gc_size(105,2).
# os(105,'windows').
# weight(105,2.1).
# comments(105,'').
#
#
# % Facts for Lenovo 300 300-15ISK 80Q700UGIN
# laptop(106).
# brand(106,'Lenovo').
# model(106,'300 300-15ISK 80Q700UGIN').
# ram(106,4).
# hd_type(106,'hdd').
# hd_size(106,1024).
# screen_size(106,15.6).
# price(106,47990).
# processor_brand(106,'intel').
# processor_model(106,'i5').
# clock_speed(106,2.3).
# gc_brand(106,'amd').
# gc_size(106,2).
# os(106,'windows').
# weight(106,3.2).
# comments(106,'customer rating 3.0').
#
#
# % Facts for Dell XPS 12 Ultrabook
# laptop(107).
# brand(107,'Dell').
# model(107,'XPS 12 Ultrabook').
# ram(107,4).
# hd_type(107,'ssd').
# hd_size(107,128).
# screen_size(107,12).
# price(107,101065).
# processor_brand(107,'intel').
# processor_model(107,'i5').
# clock_speed(107,2.6).
# gc_brand(107,'intel').
# gc_size(107,0).
# os(107,'windows').
# weight(107,3.2).
#  Lithium Battery Energy Content:	  50 Watt Hours').
#
#
# % Facts for HP 15-BS580TX
# laptop(108).
# brand(108,'HP').
# model(108,'15-BS580TX').
# ram(108,8).
# hd_type(108,'hdd').
# hd_size(108,1024).
# screen_size(108,15.6).
# price(108,42999).
# processor_brand(108,'intel').
# processor_model(108,'i3 ').
# clock_speed(108,2).
# gc_brand(108,'amd').
# gc_size(108,2).
# os(108,'windows').
# weight(108,2.1).
# comments(108,'').
#
#
# % Facts for Lenovo 510 80VB00ACIH
# laptop(109).
# brand(109,'Lenovo').
# model(109,'510 80VB00ACIH').
# ram(109,4).
# hd_type(109,'hdd').
# hd_size(109,1024).
# screen_size(109,14).
# price(109,47990).
# processor_brand(109,'intel').
# processor_model(109,'i3').
# clock_speed(109,2.4).
# gc_brand(109,'intel').
# gc_size(109,2).
# os(109,'windows').
# weight(109,1.7).
# comments(109,'customer rating 4.0').
#
#
# % Facts for Acer Aspire ES-15 NX.GKYSI.010
# laptop(110).
# brand(110,'Acer').
# model(110,'Aspire ES-15 NX.GKYSI.010 ').
# ram(110,4).
# hd_type(110,'hdd').
# hd_size(110,500).
# screen_size(110,15.6).
# price(110,17990).
# processor_brand(110,'amd').
# processor_model(110,'A4-7210').
# clock_speed(110,1.8).
# gc_brand(110,'amd').
# gc_size(110,0).
# os(110,'windows').
# weight(110,2.4).
# comments(110,'').
#
#
# % Facts for Lenovo 500 80NS0072IN
# laptop(111).
# brand(111,'Lenovo').
# model(111,'500 80NS0072IN').
# ram(111,4).
# hd_type(111,'hdd').
# hd_size(111,1024).
# screen_size(111,14).
# price(111,49052).
# processor_brand(111,'intel').
# processor_model(111,'i5').
# clock_speed(111,2.3).
# gc_brand(111,'amd').
# gc_size(111,2).
# os(111,'windows').
# weight(111,2.3).
# comments(111,'customer rating 3.0').
#
#
# % Facts for HP 450-Ci3
# laptop(112).
# brand(112,'HP').
# model(112,'450-Ci3').
# ram(112,4).
# hd_type(112,'hdd').
# hd_size(112,512).
# screen_size(112,13.86).
# price(112,43113).
# processor_brand(112,'intel').
# processor_model(112,'i3').
# clock_speed(112,2.4).
# gc_brand(112,'intel').
# gc_size(112,0).
# os(112,'windows').
# weight(112,2.25).
# comments(112,'').
#
#
# % Facts for Lenovo 320S-14IKB
# laptop(113).
# brand(113,'Lenovo').
# model(113,'320S-14IKB').
# ram(113,4).
# hd_type(113,'hdd').
# hd_size(113,1024).
# screen_size(113,14).
# price(113,48449).
# processor_brand(113,'intel').
# processor_model(113,'i5').
# clock_speed(113,3.1).
# gc_brand(113,'intel').
# gc_size(113,2).
# os(113,'windows').
# weight(113,1.7).
# comments(113,'customer rating 3.1').
#
#
# % Facts for Acer Aspire R3-131T
# laptop(114).
# brand(114,'Acer').
# model(114,'Aspire R3-131T ').
# ram(114,4).
# hd_type(114,'hdd').
# hd_size(114,500).
# screen_size(114,11.6).
# price(114,26490).
# processor_brand(114,'intel').
# processor_model(114,'Pentium N3700').
# clock_speed(114,1.6).
# gc_brand(114,'intel').
# gc_size(114,0).
# os(114,'windows').
# weight(114,1.58).
# comments(114,'').
#
#
# % Facts for HP 15-be001TX
# laptop(115).
# brand(115,'HP').
# model(115,'15-be001TX').
# ram(115,8).
# hd_type(115,'hdd').
# hd_size(115,1024).
# screen_size(115,15.6).
# price(115,43990).
# processor_brand(115,'intel').
# processor_model(115,'i5').
# clock_speed(115,2.3).
# gc_brand(115,'amd').
# gc_size(115,2).
# os(115,'windows').
# weight(115,2.19).
# comments(115,'').
#
#
# % Facts for HP 15-ac123tx
# laptop(116).
# brand(116,'HP').
# model(116,'15-ac123tx').
# ram(116,4).
# hd_type(116,'hdd').
# hd_size(116,1024).
# screen_size(116,15.6).
# price(116,44000).
# processor_brand(116,'intel').
# processor_model(116,'i5').
# clock_speed(116,2.2).
# gc_brand(116,'amd').
# gc_size(116,2).
# os(116,'windows').
# weight(116,2.19).
# comments(116,'').
#
#
# % Facts for Acer Aspire Es1-572-38Cy
# laptop(117).
# brand(117,'Acer').
# model(117,'Aspire Es1-572-38Cy').
# ram(117,4).
# hd_type(117,'hdd').
# hd_size(117,1024).
# screen_size(117,15.6).
# price(117,24890).
# processor_brand(117,'intel').
# processor_model(117,'i3').
# clock_speed(117,2.3).
# gc_brand(117,'intel').
# gc_size(117,0).
# os(117,'linux').
# weight(117,3.36).
# comments(117,'').
#
#
# % Facts for Alienware OEM
# laptop(118).
# brand(118,'Alienware').
# model(118,'OEM').
# ram(118,16).
# hd_type(118,'hdd').
# hd_size(118,1024).
# screen_size(118,15.6).
# price(118,151258).
# processor_brand(118,'intel').
# processor_model(118,'i7').
# clock_speed(118,2.6).
# gc_brand(118,'nvidia').
# gc_size(118,4).
# os(118,'windows').
# weight(118,3.18).
#  Audio: Klipsch Audio').
#
#
# % Facts for Acer A315-21G NX.GNPSI.002
# laptop(119).
# brand(119,'Acer').
# model(119,'A315-21G NX.GNPSI.002 ').
# ram(119,4).
# hd_type(119,'hdd').
# hd_size(119,500).
# screen_size(119,15.6).
# price(119,24990).
# processor_brand(119,'intel').
# processor_model(119,'i3').
# clock_speed(119,2).
# gc_brand(119,'intel').
# gc_size(119,0).
# os(119,'linux').
# weight(119,2.1).
# comments(119,'').
#
#
# % Facts for Alienware 13 Y560901IN9
# laptop(120).
# brand(120,'Alienware').
# model(120,'13 Y560901IN9').
# ram(120,8).
# hd_type(120,'hdd').
# hd_size(120,1024).
# screen_size(120,13).
# price(120,117299).
# processor_brand(120,'intel').
# processor_model(120,'i5').
# clock_speed(120,2.7).
# gc_brand(120,'nvidia').
# gc_size(120,2).
# os(120,'windows').
# weight(120,2.5).
# comments(120,'').
#
#
# % Facts for HP 245 G4,P1b38PA
# laptop(121).
# brand(121,'HP').
# model(121,'245 G4,P1b38PA').
# ram(121,4).
# hd_type(121,'ssd').
# hd_size(121,1024).
# screen_size(121,15.6).
# price(121,21999).
# processor_brand(121,'amd').
# processor_model(121,'E2-7110').
# clock_speed(121,1.8).
# gc_brand(121,'amd').
# gc_size(121,0).
# os(121,'linux').
# weight(121,2.93).
# comments(121,'').
#
#
# % Facts for HP N5Y13UA#ABA
# laptop(122).
# brand(122,'HP').
# model(122,'N5Y13UA#ABA').
# ram(122,4).
# hd_type(122,'hdd').
# hd_size(122,500).
# screen_size(122,15.6).
# price(122,41134).
# processor_brand(122,'intel').
# processor_model(122,'i5').
# clock_speed(122,2.3).
# gc_brand(122,'amd').
# gc_size(122,2).
# os(122,'windows').
# weight(122,2.1).
# comments(122,'').
#
#
# % Facts for Dell Inspiron 15 3551
# laptop(123).
# brand(123,'Dell').
# model(123,'Inspiron 15 3551').
# ram(123,2).
# hd_type(123,'hdd').
# hd_size(123,500).
# screen_size(123,15.6).
# price(123,23000).
# processor_brand(123,'intel').
# processor_model(123,'Pentium').
# clock_speed(123,2.16).
# gc_brand(123,'intel').
# gc_size(123,0).
# os(123,'linux').
# weight(123,3.12).
# comments(123,'Integrated graphics').
#
#
# % Facts for Alienware ANW17-2143SLV
# laptop(124).
# brand(124,'Alienware').
# model(124,'ANW17-2143SLV').
# ram(124,8).
# hd_type(124,'hdd').
# hd_size(124,1024).
# screen_size(124,17.3).
# price(124,178427).
# processor_brand(124,'intel').
# processor_model(124,'i7').
# clock_speed(124,2.5).
# gc_brand(124,'nvidia').
# gc_size(124,3).
# os(124,'windows').
# weight(124,3.8).
# comments(124,'17.3 inch FHD (1920 x 1080) IPS-Panel Anti-Glare 300-nits Display').
#
#
# % Facts for HP 15-ac118tu
# laptop(125).
# brand(125,'HP').
# model(125,'15-ac118tu').
# ram(125,4).
# hd_type(125,'ssd').
# hd_size(125,500).
# screen_size(125,15.6).
# price(125,23990).
# processor_brand(125,'intel').
# processor_model(125,'Pentium N3825U').
# clock_speed(125,1.9).
# gc_brand(125,'intel').
# gc_size(125,0).
# os(125,'linux').
# weight(125,3.03).
# comments(125,'Intel Integrated Graphics').
#
#
# % Facts for Acer E5-575 NX.GE6SI.016
# laptop(126).
# brand(126,'Acer').
# model(126,'E5-575 NX.GE6SI.016').
# ram(126,4).
# hd_type(126,'hdd').
# hd_size(126,1024).
# screen_size(126,15.6).
# price(126,34700).
# processor_brand(126,'intel').
# processor_model(126,'i5').
# clock_speed(126,2.5).
# gc_brand(126,'nvidia').
# gc_size(126,0).
# os(126,'linux').
# weight(126,2.2).
# comments(126,'').
#
#
# % Facts for HP 15-AY542TU
# laptop(127).
# brand(127,'HP').
# model(127,'15-AY542TU').
# ram(127,4).
# hd_type(127,'hdd').
# hd_size(127,1024).
# screen_size(127,15.6).
# price(127,28590).
# processor_brand(127,'intel').
# processor_model(127,'i3').
# clock_speed(127,2).
# gc_brand(127,'intel').
# gc_size(127,0).
# os(127,'linux').
# weight(127,2.19).
# comments(127,'').
#
#
# % Facts for HP 245 G5
# laptop(128).
# brand(128,'HP').
# model(128,'245 G5').
# ram(128,4).
# hd_type(128,'hdd').
# hd_size(128,500).
# screen_size(128,14).
# price(128,40199).
# processor_brand(128,'amd').
# processor_model(128,'APU Dual Core A4').
# clock_speed(128,1.8).
# gc_brand(128,'amd').
# gc_size(128,2).
# os(128,'windows').
# weight(128,1.8).
# comments(128,'').
#
#
# % Facts for Acer Aspire R3-131T 2017
# laptop(129).
# brand(129,'Acer').
# model(129,'Aspire R3-131T 2017 ').
# ram(129,4).
# hd_type(129,'hdd').
# hd_size(129,500).
# screen_size(129,11.6).
# price(129,27199).
# processor_brand(129,'intel').
# processor_model(129,'Pentium N3710').
# clock_speed(129,1.6).
# gc_brand(129,'intel').
# gc_size(129,0).
# os(129,'windows').
# weight(129,2.4).
# comments(129,'').
#
#
# % Facts for Dell Inspiron 5558
# laptop(130).
# brand(130,'Dell').
# model(130,'Inspiron 5558').
# ram(130,2).
# hd_type(130,'hdd').
# hd_size(130,500).
# screen_size(130,15.6).
# price(130,37790).
# processor_brand(130,'intel').
# processor_model(130,'I3').
# clock_speed(130,1.7).
# gc_brand(130,'intel').
# gc_size(130,0).
# os(130,'windows').
# weight(130,1).
# comments(130,'').
#
#
# % Facts for HP 15- BS547TU
# laptop(131).
# brand(131,'HP').
# model(131,'15- BS547TU').
# ram(131,4).
# hd_type(131,'ssd').
# hd_size(131,500).
# screen_size(131,15.6).
# price(131,26299).
# processor_brand(131,'intel').
# processor_model(131,'Pentium N3710  ').
# clock_speed(131,1.6).
# gc_brand(131,0).
# gc_size(131,0).
# os(131,'windows').
# weight(131,2.1).
# comments(131,'Integrated Graphics').
#
#
# % Facts for Alienware 17R3 1471045648
# laptop(132).
# brand(132,'Alienware').
# model(132,'17R3 1471045648').
# ram(132,8).
# hd_type(132,'hdd').
# hd_size(132,1024).
# screen_size(132,17.3).
# price(132,150453).
# processor_brand(132,'intel').
# processor_model(132,'i7').
# clock_speed(132,2.6).
# gc_brand(132,'nvidia').
# gc_size(132,3).
# os(132,'windows').
# weight(132,3.8).
# comments(132,'').
#
#
# % Facts for HP 11-ad022TU
# laptop(133).
# brand(133,'HP').
# model(133,'11-ad022TU').
# ram(133,4).
# hd_type(133,'hdd').
# hd_size(133,1024).
# screen_size(133,11.6).
# price(133,40490).
# processor_brand(133,'intel').
# processor_model(133,'i3').
# clock_speed(133,2.4).
# gc_brand(133,'amd').
# gc_size(133,0).
# os(133,'windows').
# weight(133,1.39).
# comments(133,'').
#
#
# % Facts for HP 15-BE002TU
# laptop(134).
# brand(134,'HP').
# model(134,'15-BE002TU').
# ram(134,4).
# hd_type(134,'hdd').
# hd_size(134,1024).
# screen_size(134,15.6).
# price(134,25248).
# processor_brand(134,'intel').
# processor_model(134,'Pentium N3710').
# clock_speed(134,1.6).
# gc_brand(134,'intel').
# gc_size(134,0).
# os(134,'linux').
# weight(134,2.19).
# comments(134,'').
#
#
# % Facts for Acer ASPIRE ES1-572-33M8
# laptop(135).
# brand(135,'Acer').
# model(135,'ASPIRE ES1-572-33M8').
# ram(135,4).
# hd_type(135,'hdd').
# hd_size(135,1024).
# screen_size(135,15.6).
# price(135,33990).
# processor_brand(135,'intel').
# processor_model(135,'i3').
# clock_speed(135,2).
# gc_brand(135,'intel').
# gc_size(135,0).
# os(135,'windows').
# weight(135,3).
# comments(135,'').
#
#
# % Facts for HP 15-ay008TX
# laptop(136).
# brand(136,'HP').
# model(136,'15-ay008TX').
# ram(136,4).
# hd_type(136,'hdd').
# hd_size(136,1024).
# screen_size(136,15.6).
# price(136,40890).
# processor_brand(136,'intel').
# processor_model(136,'i5').
# clock_speed(136,2.3).
# gc_brand(136,'amd').
# gc_size(136,2).
# os(136,'windows').
# weight(136,2.19).
# comments(136,'').
#
#
# % Facts for HP  Pavilion 15-AU624TX
# laptop(137).
# brand(137,'HP ').
# model(137,'Pavilion 15-AU624TX').
# ram(137,4).
# hd_type(137,'hdd').
# hd_size(137,1024).
# screen_size(137,15.6).
# price(137,58988).
# processor_brand(137,'intel').
# processor_model(137,'i5').
# clock_speed(137,2.5).
# gc_brand(137,'nvidia').
# gc_size(137,4).
# os(137,'windows').
# weight(137,2.04).
# comments(137,'').
#
#
# % Facts for Dell Inspiron i3168
# laptop(138).
# brand(138,'Dell').
# model(138,'Inspiron i3168').
# ram(138,2).
# hd_type(138,'ssd').
# hd_size(138,32).
# screen_size(138,11.6).
# price(138,37274).
# processor_brand(138,'intel').
# processor_model(138,'Celeron N3060').
# clock_speed(138,1.6).
# gc_brand(138,'intel').
# gc_size(138,0).
# os(138,'windows').
# weight(138,1.45).
# comments(138,'').
#
#
# % Facts for HP 15-bg007AU
# laptop(139).
# brand(139,'HP').
# model(139,'15-bg007AU').
# ram(139,4).
# hd_type(139,'ssd').
# hd_size(139,500).
# screen_size(139,15.6).
# price(139,23990).
# processor_brand(139,'amd').
# processor_model(139,'A6-7310').
# clock_speed(139,2).
# gc_brand(139,'amd').
# gc_size(139,0).
# os(139,'windows').
# weight(139,2.5).
# comments(139,'').
#
#
# % Facts for HP  13-s101TU
# laptop(140).
# brand(140,'HP ').
# model(140,'13-s101TU').
# ram(140,4).
# hd_type(140,'hdd').
# hd_size(140,1024).
# screen_size(140,13.3).
# price(140,57900).
# processor_brand(140,'intel').
# processor_model(140,'i5').
# clock_speed(140,2.3).
# gc_brand(140,'intel').
# gc_size(140,0).
# os(140,'windows').
# weight(140,1.71).
# comments(140,'').
#
#
# % Facts for Acer ASPIRE E5-575
# laptop(141).
# brand(141,'Acer').
# model(141,'ASPIRE E5-575 ').
# ram(141,4).
# hd_type(141,'hdd').
# hd_size(141,1024).
# screen_size(141,15.6).
# price(141,27280).
# processor_brand(141,'intel').
# processor_model(141,'i3').
# clock_speed(141,2.3).
# gc_brand(141,0).
# gc_size(141,2).
# os(141,'linux').
# weight(141,1).
# comments(141,'').
#
#
# % Facts for HP M2C39UA#ABA
# laptop(142).
# brand(142,'HP').
# model(142,'M2C39UA#ABA').
# ram(142,2).
# hd_type(142,'ssd').
# hd_size(142,32).
# screen_size(142,14).
# price(142,41224).
# processor_brand(142,'amd').
# processor_model(142,'E1-6015').
# clock_speed(142,1.4).
# gc_brand(142,'nvidia').
# gc_size(142,0).
# os(142,'windows').
# weight(142,1.9).
# comments(142,'').
#
#
# % Facts for HP 1EK01PA
# laptop(143).
# brand(143,'HP').
# model(143,'1EK01PA').
# ram(143,4).
# hd_type(143,'hdd').
# hd_size(143,1024).
# screen_size(143,15.6).
# price(143,41380).
# processor_brand(143,'intel').
# processor_model(143,'i5').
# clock_speed(143,3.1).
# gc_brand(143,'amd').
# gc_size(143,2).
# os(143,'windows').
# weight(143,2.3).
# comments(143,'').
#
#
# % Facts for HP  Pavilion 15-AU006TX
# laptop(144).
# brand(144,'HP ').
# model(144,'Pavilion 15-AU006TX').
# ram(144,8).
# hd_type(144,'hdd').
# hd_size(144,1024).
# screen_size(144,15.6).
# price(144,57000).
# processor_brand(144,'intel').
# processor_model(144,'i5').
# clock_speed(144,2.3).
# gc_brand(144,'nvidia').
# gc_size(144,4).
# os(144,'windows').
# weight(144,2.9).
# comments(144,'').
#
#
# % Facts for Acer Aspire ES 15
# laptop(145).
# brand(145,'Acer').
# model(145,'Aspire ES 15').
# ram(145,4).
# hd_type(145,'hdd').
# hd_size(145,1024).
# screen_size(145,15.6).
# price(145,19589).
# processor_brand(145,'amd').
# processor_model(145,'E1-7010').
# clock_speed(145,1.5).
# gc_brand(145,'amd').
# gc_size(145,0).
# os(145,'linux').
# weight(145,2.4).
# comments(145,'').
#
#
# % Facts for Microsoft Surface Pro 4 CR5-00028
# laptop(146).
# brand(146,'Microsoft').
# model(146,'Surface Pro 4 CR5-00028').
# ram(146,4).
# hd_type(146,'ssd').
# hd_size(146,128).
# screen_size(146,12.3).
# price(146,66500).
# processor_brand(146,'intel').
# processor_model(146,'i5').
# clock_speed(146,1.8).
# gc_brand(146,'intel').
# gc_size(146,0).
# os(146,'windows').
# weight(146,0.78).
#  ').
#
#
# % Facts for HP E4X93PA
# laptop(147).
# brand(147,'HP').
# model(147,'E4X93PA').
# ram(147,2).
# hd_type(147,'ssd').
# hd_size(147,64).
# screen_size(147,10.1).
# price(147,41599).
# processor_brand(147,'intel').
# processor_model(147,'i3').
# clock_speed(147,1.8).
# gc_brand(147,'nvidia').
# gc_size(147,0).
# os(147,'windows').
# weight(147,1.26).
# comments(147,'').
#
#
# % Facts for HP 15-AY079TX
# laptop(148).
# brand(148,'HP').
# model(148,'15-AY079TX').
# ram(148,8).
# hd_type(148,'hdd').
# hd_size(148,1024).
# screen_size(148,15.6).
# price(148,41850).
# processor_brand(148,'intel').
# processor_model(148,'i3').
# clock_speed(148,2).
# gc_brand(148,'amd').
# gc_size(148,0).
# os(148,'windows').
# weight(148,2.2).
# comments(148,'').
#
#
# % Facts for Microsoft Surface Pro 4 CR3-00022
# laptop(149).
# brand(149,'Microsoft').
# model(149,'Surface Pro 4 CR3-00022').
# ram(149,8).
# hd_type(149,'ssd').
# hd_size(149,256).
# screen_size(149,12.3).
# price(149,88900).
# processor_brand(149,'intel').
# processor_model(149,'i5').
# clock_speed(149,1.8).
# gc_brand(149,'intel').
# gc_size(149,0).
# os(149,'windows').
# weight(149,0.79).
#  Surface Pen included').
#
#
# % Facts for Acer Aspire SW3-016
# laptop(150).
# brand(150,'Acer').
# model(150,'Aspire SW3-016 ').
# ram(150,2).
# hd_type(150,'ssd').
# hd_size(150,32).
# screen_size(150,10.1).
# price(150,13872).
# processor_brand(150,'intel').
# processor_model(150,'Atom Z8300').
# clock_speed(150,1.44).
# gc_brand(150,'intel').
# gc_size(150,0).
# os(150,'windows').
# weight(150,1.2).
# comments(150,'').
#
#
# % Facts for Microsoft Surface Pro 4 CQ9-00016
# laptop(151).
# brand(151,'Microsoft').
# model(151,'Surface Pro 4 CQ9-00016').
# ram(151,8).
# hd_type(151,'ssd').
# hd_size(151,256).
# screen_size(151,12.3).
# price(151,122990).
# processor_brand(151,'intel').
# processor_model(151,'i7').
# clock_speed(151,1.8).
# gc_brand(151,'intel').
# gc_size(151,0).
# os(151,'windows').
# weight(151,0.79).
#  Surface Pen included').
#
#
# % Facts for HP  ProBook 450 G4 Notebook
# laptop(152).
# brand(152,'HP ').
# model(152,'ProBook 450 G4 Notebook').
# ram(152,4).
# hd_type(152,'hdd').
# hd_size(152,1024).
# screen_size(152,15.6).
# price(152,56197).
# processor_brand(152,'intel').
# processor_model(152,'i5').
# clock_speed(152,2.5).
# gc_brand(152,'intel').
# gc_size(152,0).
# os(152,'linux').
# weight(152,1).
# comments(152,'').
#
#
# % Facts for Microsoft Surface Laptop DAG-00001
# laptop(153).
# brand(153,'Microsoft').
# model(153,'Surface Laptop DAG-00001').
# ram(153,8).
# hd_type(153,'ssd').
# hd_size(153,256).
# screen_size(153,13.5).
# price(153,171901).
# processor_brand(153,'intel').
# processor_model(153,'i5').
# clock_speed(153,1.8).
# gc_brand(153,'intel').
# gc_size(153,0).
# os(153,'windows').
# weight(153,1.2).
# comments(153,'Integrated Graphics').
#
#
# % Facts for HP  Pavilion15t
# laptop(154).
# brand(154,'HP ').
# model(154,'Pavilion15t').
# ram(154,8).
# hd_type(154,'hdd').
# hd_size(154,1024).
# screen_size(154,15).
# price(154,56992).
# processor_brand(154,'intel').
# processor_model(154,'i5').
# clock_speed(154,2.5).
# gc_brand(154,'nvidia').
# gc_size(154,2).
# os(154,'windows').
# weight(154,2.8).
# comments(154,'').
#
#
# % Facts for Microsoft Surface Book CR9-00001
# laptop(155).
# brand(155,'Microsoft').
# model(155,'Surface Book CR9-00001').
# ram(155,8).
# hd_type(155,'ssd').
# hd_size(155,128).
# screen_size(155,13.5).
# price(155,143857).
# processor_brand(155,'intel').
# processor_model(155,'i5').
# clock_speed(155,1.8).
# gc_brand(155,'intel').
# gc_size(155,0).
# os(155,'windows').
# weight(155,1.6).
# comments(155,'').
#
#
# % Facts for Microsoft Surface Book CR9-00013
# laptop(156).
# brand(156,'Microsoft').
# model(156,'Surface Book CR9-00013').
# ram(156,8).
# hd_type(156,'ssd').
# hd_size(156,128).
# screen_size(156,13.5).
# price(156,178799).
# processor_brand(156,'intel').
# processor_model(156,'i5').
# clock_speed(156,1.8).
# gc_brand(156,'intel').
# gc_size(156,0).
# os(156,'windows').
# weight(156,1.5).
# comments(156,'').
#
#
# % Facts for Lenovo IdeaPad 520-15IKB
# laptop(157).
# brand(157,'Lenovo').
# model(157,'IdeaPad 520-15IKB').
# ram(157,8).
# hd_type(157,'hdd').
# hd_size(157,1024).
# screen_size(157,15.6).
# price(157,58990).
# processor_brand(157,'intel').
# processor_model(157,'i5').
# clock_speed(157,3.1).
# gc_brand(157,'nvidia').
# gc_size(157,4).
# os(157,'windows').
# weight(157,2.2).
# comments(157,'Dolby Audio').
#
#
# % Facts for Lenovo IdeaPad 520-15IKB
# laptop(158).
# brand(158,'Lenovo').
# model(158,'IdeaPad 520-15IKB').
# ram(158,8).
# hd_type(158,'hdd').
# hd_size(158,2048).
# screen_size(158,15.6).
# price(158,61000).
# processor_brand(158,'intel').
# processor_model(158,'i5').
# clock_speed(158,3.1).
# gc_brand(158,'nvidia').
# gc_size(158,4).
# os(158,'windows').
# weight(158,2.2).
# comments(158,'Dolby Audio').
#
#
# % Facts for Lenovo IdeaPad 520-15IKB 80YL00RXIN
# laptop(159).
# brand(159,'Lenovo').
# model(159,'IdeaPad 520-15IKB 80YL00RXIN ').
# ram(159,8).
# hd_type(159,'hdd').
# hd_size(159,1024).
# screen_size(159,15.6).
# price(159,69990).
# processor_brand(159,'intel').
# processor_model(159,'i7').
# clock_speed(159,3.5).
# gc_brand(159,'nvidia').
# gc_size(159,4).
# os(159,'windows').
# weight(159,2.2).
# comments(159,'Core i7-7500U 7th Gen processor, Dolby Audio').
#
#
# % Facts for Asus X540YA-XO290D
# laptop(160).
# brand(160,'Asus').
# model(160,'X540YA-XO290D').
# ram(160,4).
# hd_type(160,'hdd').
# hd_size(160,1024).
# screen_size(160,15.6).
# price(160,19990).
# processor_brand(160,'amd').
# processor_model(160,'APU Quad Core E2').
# clock_speed(160,1.8).
# gc_brand(160,'amd').
# gc_size(160,0).
# os(160,'linux').
# weight(160,2).
# comments(160,'').
#
#
# % Facts for Asus  P2420SA
# laptop(161).
# brand(161,'Asus ').
# model(161,'P2420SA').
# ram(161,4).
# hd_type(161,'hdd').
# hd_size(161,500).
# screen_size(161,14).
# price(161,22290).
# processor_brand(161,'intel').
# processor_model(161,'Pentium Quad Core').
# clock_speed(161,1.6).
# gc_brand(161,'intel').
# gc_size(161,0).
# os(161,'linux').
# weight(161,1.95).
# comments(161,'').
#
#
# % Facts for Asus X540LA-XX596D
# laptop(162).
# brand(162,'Asus').
# model(162,'X540LA-XX596D').
# ram(162,4).
# hd_type(162,'hdd').
# hd_size(162,1024).
# screen_size(162,15.6).
# price(162,26990).
# processor_brand(162,'intel').
# processor_model(162,'i3 5th gen').
# clock_speed(162,2).
# gc_brand(162,'intel').
# gc_size(162,0).
# os(162,'linux').
# weight(162,1.9).
# comments(162,'').
#
#
# % Facts for Asus X541UA-GO1345D
# laptop(163).
# brand(163,'Asus').
# model(163,'X541UA-GO1345D').
# ram(163,4).
# hd_type(163,'hdd').
# hd_size(163,1024).
# screen_size(163,15.6).
# price(163,27730).
# processor_brand(163,'intel').
# processor_model(163,'i3 6th gen').
# clock_speed(163,2).
# gc_brand(163,'intel').
# gc_size(163,0).
# os(163,'linux').
# weight(163,1.84).
# comments(163,'').
#
#
# % Facts for Asus A555LF
# laptop(164).
# brand(164,'Asus').
# model(164,'A555LF').
# ram(164,8).
# hd_type(164,'hdd').
# hd_size(164,1024).
# screen_size(164,15.6).
# price(164,39961).
# processor_brand(164,'intel').
# processor_model(164,'i3 4th gen').
# clock_speed(164,1.7).
# gc_brand(164,'nvidia').
# gc_size(164,2).
# os(164,'windows').
# weight(164,2.3).
# comments(164,'').
#
#
# % Facts for Asus X555LA-XX172D
# laptop(165).
# brand(165,'Asus').
# model(165,'X555LA-XX172D').
# ram(165,4).
# hd_type(165,'hdd').
# hd_size(165,500).
# screen_size(165,15.6).
# price(165,28489).
# processor_brand(165,'intel').
# processor_model(165,'i3 4th gen').
# clock_speed(165,1.9).
# gc_brand(165,'intel').
# gc_size(165,0).
# os(165,'linux').
# weight(165,2.3).
# comments(165,'').
#
#
# % Facts for Asus X554LD
# laptop(166).
# brand(166,'Asus').
# model(166,'X554LD').
# ram(166,2).
# hd_type(166,'hdd').
# hd_size(166,500).
# screen_size(166,15.6).
# price(166,29199).
# processor_brand(166,'intel').
# processor_model(166,'i3 4th gen').
# clock_speed(166,1.9).
# gc_brand(166,'intel').
# gc_size(166,1).
# os(166,'linux').
# weight(166,2.3).
# comments(166,'').
#
#
# % Facts for Asus X550LAV-XX771D
# laptop(167).
# brand(167,'Asus').
# model(167,'X550LAV-XX771D').
# ram(167,2).
# hd_type(167,'hdd').
# hd_size(167,500).
# screen_size(167,15.6).
# price(167,29990).
# processor_brand(167,'intel').
# processor_model(167,'i3 4th gen').
# clock_speed(167,1.7).
# gc_brand(167,'intel').
# gc_size(167,0).
# os(167,'linux').
# weight(167,2.5).
# comments(167,'').
#
#
# % Facts for Asus X540LA-XX538T
# laptop(168).
# brand(168,'Asus').
# model(168,'X540LA-XX538T').
# ram(168,4).
# hd_type(168,'hdd').
# hd_size(168,1024).
# screen_size(168,15.6).
# price(168,30899).
# processor_brand(168,'intel').
# processor_model(168,'i3 5th gen').
# clock_speed(168,2).
# gc_brand(168,'intel').
# gc_size(168,0).
# os(168,'windows').
# weight(168,2.3).
# comments(168,'').
